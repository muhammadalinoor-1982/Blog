# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadalinoor-1982/Blog/blob/master/ML_Basics_for_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Learning:
# 1. Regression: If Output Features are Numerical (Numbers)
# 2. Classification: If Output Features are Categorical (String)

# %% [markdown]
# # Unsupervised Learning:
#
# 1. Clustering: Detecting and Analyzing Data to Create Different Levels or Group Data
# 2. Dimensionality Reduction: Reduce less Important Column it's called Feature Extraction. Example: PCA, Visualization
# 3. Anomaly Detection: Detect OUTLIERS and Remove it
# 4. Association Rule Learning: Correlations between Features

# %% [markdown]
# # Classification Algorithm
#
# 1. KNN (K-Nearest Neighbors)
# 2. DT (Decision Tree)
# 3. RF (Random Forest)
# 4. NB (Naive Bayes)
# 5. SVM (Support Vector Machine)
# 6. LR (Logistic regression)
# 7. AB (Ada Boost)
# 8. Gradient
# 9. Voting

# %% [markdown]
# # List of Encoder
#
# 1. Label Encoder
# 2. Ordinal Encoder
# 3. One Hot Encoder
# 4. Get_Dummies Encoder
# 5. Count Encoder
# 6. Target Encoder
# 7. Frequency Encoder
# 8. Binary Encoder
# 9. Feature Hashing

# %% [markdown]
# # List of EDA
#
# 1. Outliers
# 2. Overfitted
# 3. Undefeated
# 4. Correlation
# 5. ROC Curve
# 6. AUC Curve

# %% [markdown]
# # List of Feature Scaling
#
# 1. Normalization
# 2. STD (Standard deviation)

# %% [markdown]
# 1. Univariate Analysis
# 2. Byvariate Analysis
# 3. Multivariet Analysis

# %% [markdown]
# Types of Dataset:
# 1. Numerical Data
# 2. Categorical Data
# 3. Ordinal Data
#
# Steps of Data Pre-Processing ro Exploratory Data Analysis (EDA):
# 1. Collect Dataset
# 2. Import Python Libraries. Example: Numpy, Pandas, Matplotlib, Seaborn
# 3. Include Dataset in CSV Format
# 4. Find and Manage Missing Values
# 5. Apply Encoder (OneHotEncoder, LabelEcoder, OrdinalEncoder)
# 6. Split Dataset for Train and Test
# 7. Feature Scaling

# %% [markdown]
# Basic 7 Questions for Dataset:
# 1. How Big is the Data ?  Code >>> df.shape
# 2. How does the Data look like ? Code >>> df.head() or df.sample(5) Note: sample() use for random Data
# 3. What is the Data Type of Columns ? Code >>> df.info()
# 4. Are there any missing values ?  Code >>> df.isnull().sum()
# 5. How Does The Data Look Mathematically ? Code >>> df.describe()
# 6. Are there any Duplicate Values ? Code >>> df.duplicated().sum() IF get Any Duplicate Values then use df.drop_duplicates()
# 7. How is the Corelation Between Columns ? Code >>> df.corr()

# %% [markdown]
# Show Data Fream from top with mentioned number of value ? Code >>> df.head(10)
#
# Show Data Fream from bottom with mentioned number of value ? Code >>> df.tail(10)
#
# Show All information of Dataset ? Code >>> df.info()
#
# Show Number of Row and Columns in a Data Fream ? Code >>> df.shape
#
# Show the Random Saple of Dataset ? Code >>> df.sample(3)
#
# Show, is there any duplicate or repeted value in the data fream ? Code >>> df.duplicated()
#
# Show, number of duplicate or repeted value in the data fream  ? Code >>> df.duplicated().sum()
#
# How to Drop Duplicate Values ? Code >>> df.drop_duplicates()
#
# Show Number of Unique value in the columns of a data fream ? Code >>> df.nuniqe()
#
# Show All Columns Name in the Data Fream ? Code >>> df.columns
#
# Show How many columns in the Data Fream ? Code >>> print(len(df.columns))
#
# Show the Name of Entities in the Column ? Code >>> df['embark_town'].unique()
#
# Show the Number of Entities in the Column ? Code >>> df['embark_town'].nunique()
#
# Show How many number of each Entity in the column ? Code >>> df['species'].value_counts()
#
# Show all kind of Data Type in the Dataset ? Code >>> df.dtypes
#
# Show is there any Null Field in the Dataset ? Code >>> df.isnull()
#
# Show Column wise all null values in the Dataset ? Code >>> df.isnull().sum()
#
# Show Total number of Null Values in the Dataset ? Code >>> df.isnull().sum().sum()
#
# How Does The Data Look Mathematically ? Code >>> df.describe()
#
# How is the Corelation Between Columns ? Code >>> df.corr()

# %% [markdown]
# #**What si Data Cleaning ?**
# Data cleaning involves identifying and correcting errors in the dataset, such as dealing with **missing** or **inconsistent data**, **removing duplicates**, and **handling outliers**.

# %% [markdown]
# #**How to call a row ?**

# %%
df.loc[30] # 30 is index of datapoint
# Out:
# Unnamed: 0          30
# sepal_length       4.8
# sepal_width        3.1
# petal_length       1.6
# petal_width        0.2
# species         setosa
# Name: 30, dtype: object

# %% [markdown]
# #**How to call a column ?**

# %%
df['species'] # "species" is name of a column
# Out:
# 0          setosa
# 1          setosa
# 2          setosa
# 3          setosa
# 4          setosa
#           ...
# 145    versicolor
# 146    versicolor
# 147    versicolor
# 148    versicolor
# 149    versicolor
# Name: species, Length: 150, dtype: object

# %% [markdown]
# #**How to drop column ?**

# %%
# Drop single column
df = df.drop('species', axis=1)

# Drop multiple columns
df = df.drop(['sepal_length', '	sepal_width'], axis=1)

# %% [markdown]
# #**How to drop row ?**

# %%
# Drop Single row
df.drop([7], axis=0) # 7 is a index of row

#Drop Multiple row
df.drop([7,8,9,10], axis=0)

# %% [markdown]
# #**How to Check duplicate ?**

# %%
# to check for duplicate values in a particular column

df.duplicated('column1')

# to check for duplicate values in some specific columns

df.duplicated(['column1', 'column2', 'column3'])

# To check the number of duplicate values

df.duplicated.sum()

# %% [markdown]
# #**How to remove duplicate ?**

# %%
# Dropping duplicates

df.drop_duplicates()

# to delete duplicates from a particular column

df.drop_duplicates('column1')

# to delete duplicates from some specific columns

df.drop_duplicates(['column1', 'column2', 'column3'])

# %% [markdown]
# #**How to Display Dataset Information ?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# verginica     50
# versicolor    50
# Name: count, dtype: int64

# %% [markdown]
# #**How to Check How many Row or Datapoint in a Dataset**

# %%
df.value_counts().sum()
# Out:
# 150

# %% [markdown]
# #**How to Check How many Missing Value in a Dataset**

# %%
df.isnull().sum()
#df.notnull() # How many not null bavule in a dataset
#df.isna() # How many not null bavule in a dataset
#df.dropna() # Drops rows or columns containing missing values
#df.unique() # Finds unique values in a Dataset
# Out:
# Unnamed: 0      0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# #**max(), median() and mean()**

# %%
df['sepal_length'].min() #
# Out:
# 4.3

# %% [markdown]
# #**How to Replace Missing Values ?**

# %%
df.replace() # Replaces specific values with other values, facilitating data correction and standardization.
#df.fillna() # Fills missing values with specific values, means, medians
#df = df.fillna(method = 'pad') Fill Null values with Zero padding
# Out:
# <ipython-input-21-53fc0d9df4e3>:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df.replace()
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# ...

# %% [markdown]
# #**Scatter Plot**

# %%
sns.scatterplot(x='sepal_length', y='species', data=df, hue='petal_width', style='sepal_width', size='petal_length')
plt.show()

# %% [markdown]
# #**Bar Plot**

# %%
sns.barplot(x='sepal_length', y='species', data=df, hue='petal_length')
plt.show()

# %% [markdown]
# #**Dist Plot**

# %%
sns.distplot(df[df['species']=='setosa']['sepal_length'], hist=False)
sns.distplot(df[df['species']=='versicolor']['sepal_length'], hist=False)
sns.distplot(df[df['species']=='verginica']['sepal_length'], hist=False)
plt.show()
# Out:
# <ipython-input-25-85d7c4fc36c7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['species']=='setosa']['sepal_length'], hist=False)
# <ipython-input-25-85d7c4fc36c7>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #**PDF (Probablity Density Function)**

# %%
sns.distplot(df['sepal_length'])
plt.show()
# Out:
# <ipython-input-4-9dc1d3f8861c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])

# %% [markdown]
# #**Histogram plot**

# %%
plt.hist(df['sepal_length'], bins = 50)
plt.show()

# %% [markdown]
# #**Boxplot**

# %%
sns.boxplot(df['sepal_length'])
plt.show()

# %% [markdown]
# #**Heat Map**

# %%
sns.heatmap(pd.crosstab(df['sepal_length'], df['species']))
plt.show()

# %% [markdown]
# #**Cluster Map**

# %%
sns.clustermap(pd.crosstab(df['sepal_length'], df['petal_length']))
plt.show()

# %% [markdown]
# #**Pair Plot**

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
sns.lineplot(x='sepal_length', y='species', data=df)
plt.show()

# %% [markdown]
# #**Pivot Table**

# %%
sns.heatmap(df.pivot_table(values='sepal_length', index='species', columns='petal_length'))
plt.show()

# %% [markdown]
# #**Verious Types of Plot**
# **1. Scatter Plot (scatterplot):**
# A scatter plot is a type of graph that uses Cartesian coordinates to display values for two variables for a set of data.
#
# **2. Bar Plot (barplot):**
# A bar plot displays categorical data with rectangular bars, where the length of each bar represents the value of the corresponding category.
#
# **3. Count Plot (countplot):**
# A count plot is a bar plot that shows the frequency of occurrences for each category in a categorical variable.
#
# **4. Box Plot (boxplot):**
# A box plot displays the distribution of a dataset through its quartiles, highlighting the median, interquartile range, and potential outliers. It provides a visual summary of the data’s central tendency, dispersion, and skewness.
#
# **5. Violin Plot (violinplot):**
# A violin plot combines a box plot with a kernel density plot, showing the distribution, probability density, and central tendencies of the data.
#
# **6. Histogram (histplot):**
# A histogram displays the distribution of a continuous variable by dividing data into bins and plotting the frequency of data points in each bin.
#
# **7. Line Plot (lineplot):**
# A line plot is a type of graph that displays data points connected by straight lines, showing trends over a continuous interval or time period.
#
# **8. Heatmap (heatmap):**
# A heatmap is a graphical representation of data where values in a matrix are represented as colors.
#
# **9. Pair Plot (pairplot):**
# A pair plot (pairplot) creates a grid of scatterplots and histograms for each pair of variables in a dataset, allowing for visual exploration of relationships and distributions between variables.
#
# **10. pie Plot (pieplot):**
# A Pie Chart is a circular statistical plot that can display only one series of data.

# %% [markdown]
# #**When use Principal Component Analysis(PCA) and how does it works ?**
#
# **Defination of PCA:**
#
# PCA reduces the number of variables or features in a data set while still preserving the most important information like major trends or patterns. This reduction can decrease the time needed to train a machine learning model and helps avoid overfitting in a model.

# %% [markdown]
# #**What is Synthetic Minority Oversampling Technique (SMOTE) & how does it works ?**
#
# **Synthetic Minority Oversampling Technique (SMOTE)** is a statistical technique for increasing the number of cases in your dataset in a balanced way. The component works by generating new instances from existing minority cases that you supply as input.

# %% [markdown]
# #**Which matrix use, when balance or imbalance dataset ?**
#
# In this case, the **confusion matrix** for the classification problem shows how well our model classifies the target classes, and we arrive at the model's model's accuracy from the confusion matrix. It is calculated based on the model's **total number of `correct` predictions divided by the total number of
# predictions**.

# %% [markdown]
# #**What is confusion matrix ?**
#
# A confusion matrix is a **performance evaluation tool** in machine learning, **representing the accuracy of a classification model**. It displays the number of true positives, true negatives, false positives, and false negatives.

# %% [markdown]
# #**What is classification report ?**
#
# A classification report is a **text summary** that shows the main metrics for each class of a machine learning model. It usually includes the **precision, recall, F1-score**, and support for each class, as well as the **weighted average** of these metrics across all classes

# %% [markdown]
# #**What is F1-score ?**
#
# The F-score is a **measure of a model's accuracy on a dataset**. It is used to **evaluate binary classification systems**, which classify examples into 'positive' or 'negative'.

# %% [markdown]
# #**What is Precision ?**
#
# Precision is one indicator of a machine learning model's performance – **the quality of a positive prediction made by the model**. Precision refers to the **number of `true positives divided` by the total number of positive predictions** (i.e., the number of true positives plus the number of false positives).

# %% [markdown]
# #**What is Recall ?**
#
# Recall is a metric that **measures how often a machine learning model correctly identifies positive instances (true positives)** from all the **`actual positive samples`** in the dataset. You can **calculate recall by dividing the number of `true positives` by the number of positive instances**.

# %% [markdown]
# #**What is KNN ?**
#
# **Definitation:**
# The k-nearest neighbors (KNN) algorithm is a **`non-parametric, supervised learning classifier`**, which uses **`proximity to make classifications or predictions`** about the **`grouping of an individual data point`**.
#
# Parametric and non-parametric
# ![1658894728870.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**How to fine tune KNN parameters when it goes overfitting or underfitting ?**
#
# **Answer:**
#  Use **`cross-validation`** to select the **`optimal value of k`** for the rectification and identification of overfitting or underfitting

# %% [markdown]
# #**What is outliers ?**
#
# **Answer:**
#   An outlier is a data point **`significantly different`** from other data points in a dataset.

# %% [markdown]
# #**What is percentile value ?**
#
# **Answer:**
# Percentiles can be used to **`summarize the distribution`** of a dataset and **`identify outliers`**.

# %% [markdown]
# #**How to find outliers using box plot ?**
#
# **To detect outliers using boxplots, you can follow these steps:**
#
# 1. Arrange the data in ascending order.
# 2. Calculate the first quartile (Q1), median (Q2), and third quartile (Q3).
# 3. Determine the interquartile range (IQR) by subtracting Q1 from Q3 (IQR = Q3 – Q1).
# 4. Calculate the lower and upper bounds for outliers. The lower bound and upper bound are included in the non-outlier zone.
#
#   Lower Bound = Q1 – 1.5 * IQR
#
#   Upper Bound = Q3 + 1.5 * IQR
#
# 5. Identify any data points that fall below the lower bound or above the upper bound as outliers.
#
# #**Example:**
#
# **Given dataset:** {22, 35, 2, 4, 20, 39, 37, 102, 101, 36}
#
# **Step 1:** Arrange the data in ascending order: {2, 4, 20, 22, 35, 36, 37, 39, 101, 102}
#
# **Step 2:** Calculate Q1, Q2, and Q3:
#
# Q2 (second quartile or median) = median({2, 4, 20, 22, 35, 36, 37, 39, 101, 102}) =(35+36)/2= 35.5
#
# Q1 (first quartile) = the median of the lower half (excluding Q2) = median({2, 4, 20, 22, 35}) = 20
#
# Q3 (third quartile) = the median of the upper half (excluding Q2) = median({36, 37, 39, 101, 102}) = 39
#
# **Step 3:** Determine the IQR: IQR = Q3 – Q1 = 39 – 20 = 19
#
# **Step 4:** Calculate the lower and upper bounds for outliers:
#
# Lower Bound = Q1 – 1.5 * IQR = 20 – 1.5 * 19 = -8.5
#
# Upper Bound = Q3 + 1.5 * IQR = 39 + 1.5 * 19 = 67.5
#
# **Step 5:** Identify outliers: Any data points smaller than -8.5 or above 67.5 are considered outliers. In this dataset, we have two outliers: 101 and 102.
#
# The following figure shows the corresponding boxplot.
# ![boxplot.png](data:image/png;base64,...)

# %% [markdown]
# #**How to find outliers using violin plot ?**
#
# **Answer:**
# A long thin line coming outside from the bar – The thin line represents the rest of the distribution which is calculated by the formulae
#
# **`Lower Range:`** Q1-1.5 IQR
#
# **`Upper Range:`** Q3-1.5 IQR
#
# **`The point lying beyond this line are considered as outliers.`**

# %% [markdown]
# #**How to solve outliers problem using IQR ?**
#
# **Answer:**
# Compute the interquartile range (IQR) as the difference between **`Q3 and Q1 (IQR = Q3 – Q1)`**. Define the **`lower outlier threshold as Q1 – (1.5 * IQR)`** and the **`upper outlier threshold as Q3 + (1.5 * IQR)`**. **Identify any data points that fall below the lower threshold or above the upper threshold.**

# %% [markdown]
# #**What is overfitting ?**
#
# **Answer:**
# Overfitting occurs when an **algorithm `fits too closely` or even `exactly to its training data`**, resulting in a model that **`can't make accurate predictions`** or conclusions from any data **`other than the training data`**.

# %% [markdown]
# #**What is overfitting and underfitting ?**
# **Answer:**
# Underfit models **`experience high bias`**—they give **`inaccurate results`** for both the **training data and test set.** On the other hand, overfit models **`experience high variance`**—they give **`accurate results for the training set` but not for the test set.**

# %% [markdown]
# #**When use upscale ?**
# **Answer:**
# when you **`need to increase the pixel count` while maintaining high resolution** using deep learning image processing, such as when you **`need more pixels for large format printing` or when the pixel count is reduced due to trimming.**

# %% [markdown]
# #**Illustration of spatial downscaling and upscaling.**
# ![upscaling aand downscaling.png](data:image/png;base64,...)

# %% [markdown]
# #**What is Synthetic Minority Oversampling Technique (SMOTE) ?**
# **Answer:**
# Synthetic Minority Oversampling Technique (SMOTE) is a **statistical technique for `increasing the number` of cases in your dataset `in a balanced way`.** The component works by **`generating new instances from existing minority cases` that you supply as input.**

# %% [markdown]
# #**Standard Daviation**
#
# I)sigma is symbole of Standard Daviation
#
# II) In Standardization, Mean should be 0 and Standard Daviation should be 1
#
#     a) K-Means
#     b) KNN
#     c) ANN
#     d) PCA
#     e) Gradient Descent
#
#     Note: No Need to Apply Standardization: Decision Tree, Random Forest, Gradient Boost, XGBoost

# %% [markdown]
# # **Normalization**
#
#     a) Minmax Scaler Note: Use for Image Processing
#     b) Mean Scaler (Mean Centering)
#     c) Max Absolute Scaler Note: Use for Spars Data
#     d) Robust Scaler Note: Use for Outliers

# %% [markdown]
# # Types of Data:
#     1. Numerical   Data
#     2. Categorycal Data
#         a) Nominal Data
#         b) Ordinal Data
#             I) Label Encoder (Mostly Use for Output Column)
#             II) Ordinal Encoder (Mosly use for Input Column)

# %%
df.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    74.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      0.000000      4.300000     2.000000      1.000000     0.100000
# 25%     37.250000      5.100000     2.800000      1.600000     0.300000
# 50%     74.500000      5.800000     3.000000      4.350000     1.300000
# 75%    111.750000      6.400000     3.300000      5.100000     1.800000
# max    149.000000      7.900000     4.400000      6.900000     2.500000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/iris.csv')
df.sample(3)
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 138         138           6.0          3.0           4.8          1.8
# 111         111           6.4          2.7           5.3          1.9
# 75           75           6.6          3.0           4.4          1.4
#
#         species
# 138  versicolor
# 111  versicolor
# 75    verginica
