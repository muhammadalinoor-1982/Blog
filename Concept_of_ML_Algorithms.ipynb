# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadalinoor-1982/Blog/blob/master/Concept_of_ML_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification Algorithm
# 1. PCA (Principal Component Analysis) **`Dimentionality Reduction`**
# 2. KNN (K-Nearest Neighbors) **`Distance Metric`**
# 3. NB (Naive Bayes) **`Probability`**
#
#
# 4. SVM (Support Vector Machine) **`Linear Marginal Line`**
# 5. LR (Logistic regression) **`Linear Line`**
# 6. K-Means **`Unsupervised and Clustering`**
#
#
# 7. DT (Decision Tree) **`Based on Decision`**
# 8. RF (Random Forest) **`Majority Voting`**
# 9. XG (XG Boost) **`Error Zero`**
# 10. AB (Ada Boost) **`Stage Addition`**
# 11. Voting **`Majority Voting`**

# %% [markdown]
# #**What is PCA ?**
#
# **Answer:**
# Principal component analysis (PCA) is a **`dimensionality reduction`** and machine learning method used to **`simplify a large data set into a smaller set`** while still maintaining **`significant patterns and trends`**.
#
# **If Dataset has `so many features/Dimentions in comparison with Datapoints` then should apply PCA to reduce features**
#
# **`Use Column Standardization to reduce overfitting`**
#
# ##**`Rotate angle of θ untill findout minimum distance of axis and maximum variance of features`**
#
# **After getting `minimum distance of axis and maximum variance of features`, PCA will decide which `dimention will be reduce` or not**
#
# **`μ(Magnitude) Mean should be 0`**
#
# **`σ(Direction) Variance should be 1`**

# %% [markdown]
# #**What is KNN ?**
#
# **Definitation:**
# The k-nearest neighbors (KNN) algorithm is a **`non-parametric, supervised learning classifier`**, which uses **`proximity to make classifications or predictions`** about the **`grouping of an individual data point`**.
#
# **`Step#1` Calculate Euclidean Distance of Nearest Neighbor.**
#
# **`Step#2` Fine-Tune Different Different K Nearest Distance of Values and Select an Optimal K value.**
#
# **`Step#3` Consider Majority Voting(For Classifications)**
#
# **`Overfitting:` Small K value get Low Bias and High Variance.**
#
# **`Underfitting:` Large K value get High Bias and Low Variance.**
#
# **`Optimal:` Optimal K value will controll The Balance Between Overfitting and Underfitting.**
#
# Parametric and non-parametric
# ![1658894728870.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**How to fine tune KNN parameters when it goes overfitting or underfitting ?**
#
# **Answer:**
#  Use **`cross-validation`** to select the **`optimal value of k`** for the rectification and identification of overfitting or underfitting

# %% [markdown]
# #**What is overfitting ?**
#
# **Answer:**
# Overfitting occurs when an **algorithm `fits too closely` or even `exactly to its training data`**, resulting in a model that **`can't make accurate predictions`** or conclusions from any data **`other than the training data`**.

# %% [markdown]
# #**What is overfitting and underfitting ?**
# **Answer:**
# Underfit models **`experience high bias`**—they give **`inaccurate results`** for both the **training data and test set.** On the other hand, overfit models **`experience high variance`**—they give **`accurate results for the training set` but not for the test set.**

# %% [markdown]
# #**What is naive bayes ?**
# **Answer:**
# The Naïve Bayes classifier is a supervised machine learning algorithm that is used for classification tasks such as **`text classification`**. They use **`principles of probability` to perform classification tasks.**
#
# **According to The Bayes Theorem:**
#
#   **Step#1 `Prior Probability`**
#
#   **Step#2 `Conditional Probability`**
#
#   **Equation of Bayes Theorem:**
#
#   ![1_39U1Ln3tSdFqsfQy6ndxOA.webp](data:image/webp;base64,...)
#
#
#   **Calculation of Naive Bayes Probability**
#
# ![Naive Bayes.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #**What is laplace smoothing in Naive Bayes ?**
# **Answer:**
# Laplacian smoothing is **a technique used to `handle zero probabilities` in the training data.** In the **`context of Naive Bayes`**, it involves **`adding a small constant (here α(Alpha) is smoothing parameter and α>0 usually 1) `**to the count of each feature for each class.
#
# **▶ `If Value of α is Small Then Model will be Overfit`**
#
# **▶ `If Value of α is Large Then Model will be Underfit`**
#
# **▶ `If Value of α is Optimal Then Model will Controll The Balance`**
#
# **If Imbalanced Dataset Then Apply:**
#
# **`1. Upscale`**
#
# **`2. Downscale`**
#
# **`3. SMOTE(Synthetic Minority Oversampling Technique)`**

# %% [markdown]
# #**What is Synthetic Minority Oversampling Technique (SMOTE) ?**
# **Answer:**
# Synthetic Minority Oversampling Technique (SMOTE) is a **statistical technique for `increasing the number` of cases in your dataset `in a balanced way`.** The component works by **`generating new instances from existing minority cases` that you supply as input.**

# %% [markdown]
# #**Support Vector Machine Terminology**
#
# **`Hyperplane:`** Hyperplane is the decision boundary that is used to separate the data points of different classes in a feature space. In the case of linear classifications, it will be a linear equation i.e. wx+b = 0.
#
# **`Support Vectors:`** Support vectors are the closest data points to the hyperplane, which makes a critical role in deciding the hyperplane and margin.
#
# **`Margin:`** Margin is the distance between the support vector and hyperplane. The main objective of the support vector machine algorithm is to maximize the margin.  The wider margin indicates better classification performance.
#
# **`Kernel:`** Kernel is the mathematical function, which is used in SVM to map the original input data points into high-dimensional feature spaces, so, that the hyperplane can be easily found out even if the data points are not linearly separable in the original input space. Some of the common kernel functions are linear, polynomial, radial basis function(RBF), and sigmoid.
#
# **`Hard Margin:`** The maximum-margin hyperplane or the hard margin hyperplane is a hyperplane that properly separates the data points of different categories without any misclassifications.
#
# **`Soft Margin:`** When the data is not perfectly separable or contains outliers, SVM permits a soft margin technique. Each data point has a slack variable introduced by the soft-margin SVM formulation, which softens the strict margin requirement and permits certain misclassifications or violations. It discovers a compromise between increasing the margin and reducing violations.
#
# **`C:`** Margin maximisation and misclassification fines are balanced by the regularisation parameter C in SVM. The penalty for going over the margin or misclassifying data items is decided by it. A stricter penalty is imposed with a greater value of C, which results in a smaller margin and perhaps fewer misclassifications.
#
# **▶ `If Value of C = 1/α is Large Then Model will be Overfit`**
#
# **▶ `If Value of C = 1/α is Small Then Model will be Underfit`**
#
# **`Hinge Loss:`** A typical loss function in SVMs is hinge loss. It punishes incorrect classifications or margin violations. The objective function in SVM is frequently formed by combining it with the regularisation term.
#
# **`Dual Problem:`** A dual Problem of the optimisation problem that requires locating the Lagrange multipliers related to the support vectors can be used to solve SVM. The dual formulation enables the use of kernel tricks and more effective computing.
#
# **Popular kernel functions in SVM**
#
# **`Linear Kernel`**
#
# **`Polynomial Kernel`**
#
# **`Gaussian RBF Kernel`**
#
# **`Sigmoid`**
#
# **Build the model:**
# **`svm = SVC(kernel="rbf", gamma=0.5, C=1.0)`**
#
#
# ![support-vector-machine-algorithm.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**What is Logistic Regression ?**
#
# **Answer:**
#
# Logistic regression is defined as a supervised machine learning algorithm that accomplishes **`binary classification`** tasks by predicting the probability of an outcome, event, or observation.
#
# **Assumption: `Assume that dataset can be linearly separable`**
#
# **Range of Sigmoid Value: `Range of Sigmoid Value within 0 to 1`**
#
# **Sigmoid Squashing Formula:**
#
# ![1694183008799.png](data:image/png;base64,...)
#
# **`e is Exponential`**
#
# **Use `Normalization to reduce overfitting`**
#
# **`L1 Normalizations outcome will be 0`**
#
# **`L2 Normalizations outcome will be greater than 0`**
#
# **`L1 and L2 Normalizations will make Elastic net`**
#
#
# **`Optimization of Logistic Regression:`**
#
# ![z_equation.png](data:image/png;base64,...)
#
# **Here 'b' is a Normalization and b= `σωTω + σ|ω|`**
#
# **In Implementation: `LogisticRegrassion(panalty='12', C=i, n_jobs=-1)`**

# %% [markdown]
# #**What is Decision Tree ?**
#
# **Answer:**
# A decision tree is a **`non-parametric`** supervised learning algorithm, which is utilized for both classification and regression tasks. It has a **`hierarchical, tree structure`**, which consists of a **`root node, branches, internal nodes and leaf nodes.`**
#
# **`Entropy(S) Here, 'S' is a Symbol of Enropy`**
#
# **`Information Gain(IG)`**
#
# **`Gini(S):` Gini almost like an Entropy. Gini `donot use log`. That's why `calculation is easy`. Mostly use Gini instead of Entropy**
#
# **`Formula of IG = (Entropy of Entier Dataset) - (Entropy of all Attribute)`**
#
# **`Highest value of IG will be Root Node`**
#
# **Implementation: `DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=0)`**

# %% [markdown]
# #**What is Random Forest**
#
# ![Reandom Forest.JPG](data:image/jpeg;base64,...)
#
# **Here `Ensemble Meens 'Group'`. `Group of Decision Tree`**
#
# **Here `Bootstrap Meens 'Random Sample'`. `Random Sample take from Dataset`**
#
# **Basically Random Forest `Reduce Overfitting` as a result, Random Forest give `more accurate Prediction`**
#
# **`How Rendom Forest Works`**
#
# ![Tree.JPG](data:image/jpeg;base64,...)
#
# **Finally Prediction comeout from `bagging with Majority Voting`**
#
# **`Bagging` makes by `Bias and Variance`. Bagging `Reduce Overfitting` by ensuring `low Bias and Varience`**
#
# **Implementation: `RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=10, random_state=0, max_features=None)`**

# %% [markdown]
# #**What is XGboost ?**
#
# Full Name of XGboost is **`Extreme Gradient Boosting`**
#
# XGboos is an **`Extention`** of DecisionTree
#
# **Advantages of XGboost:**
#
#   **`1. Fast Execution`**
#
#   **`2. Best Performance`**
#
#   **`3. Ensemble Learning`**
#
# **Speed of XGboost:**
#
# **`1. Parallelization (Parallelly work in Microprocessor)`**
#
# **`2. Cache Optimization (Use Cache Memory)`**
#
# **`3. Out of Memory Computation (Not Depend on RAM)`**
#
# **Performance of XGboost:**
#
# **`1. Regularization(No Overfitting)`**
#
# **`2. Auto Pruning`**
#
# **`3. Automatically Handling Missing Value`**
#
# **XGboost Compatibility:**
#
# **`1. Compatible with The Language. Example: python, R, Julia, C++`**
#
# **`2. Execution Compatibility With Operating System. Example: Windows, Linux, MAC`**
#
# **`3. Integration Compatibility. Example: Azure,...`**
#
# **Visual Demonstration of XGboost**
#
# ![XGboost.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #**What is Adaboost ?**
#
# Answer: Adaboost is a **`stagewise additive method`**.It's aims to **`improve the accuracy`** of an **`ensemble`** by creating a series of classifiers by **`combining multiple weak learners`**.
#
# **Method# 1. `Weak Learning`**
#
# **Method# 2. `Decision Stump`**
#
# **`This is a sequential learning process and multiple decision stump`**
#
# **`Upsampling waight(waight=α) of incorrectly classified values`**
#
# **`Calculate the value of α multiply with decisiton stump`**

# %% [markdown]
# #**What is k Means clustering and how it works**
#
# **Answer:**
# K-Means clustering is an **`unsupervised learning algorithm`**. There is **`no labeled data` for this clustering**, unlike in supervised learning. K-Means performs the **division of objects into clusters that `share similarities and are dissimilar to the objects` belonging to another cluster**. The term 'K' is a number.
#
# ![K Means.JPG](data:image/jpeg;base64,...)
#
# **`Usually KMeans apply for multi-dimensional classification`**
#
# **`Claculate centroid and euclidean distance (Nearest values)`**
#
# **`Choose K value from Elbow Method (Elbow Curve)`**
#
# ![Elbow-method.png](data:image/png;base64,...)
#
# **`WCSS(Within Cluster sum of Square Distance)` Another words is INERTIA**
#
# **`Step#01:` Decide number(K) of Clusters**
#
# **`Step#02:` Initialized Centroid**
#
# **`Step#03:` Assign Cluster (Calculate euclidean distance, most nearest points)**
#
# **`Step#04:` Move Centroid into the center point of it's Cluster (Calculate the mean of X and Y of a Cluster)**
#
# **`Step#05:` Continuously assign and move Centroid untill separate the Cluster. If the Last and Present value of centroid are same then Clustering are Done, if Not then again Assign and Move Centoid Untill it fixed**

# %% [markdown]
# #**What is voting ?**
#
# **Answer:** The Voting in Sklearn is **an ensemble method that `combines multiple individual classifiers` or regressors to make predictions**. It supports both hard and soft voting strategies.
#
# **Hard Voting: Calculate `Majority` among the classifiers**
#
# **Soft Voting: Calculate `Probability Mean` of all classifiers**
#
# **Example in Implementation:**
#
# from sklearn.tree import DecisionTreeClassifier
#
# from xgboost import XGBClassifier
#
# from sklearn.ensemble import RandomForestClassifier, VotingClassifier
#
# voting_set = [
#     ('dtc', DecisionTreeClassifier()),
#     ('xgb', XGBClassifier()),
#     ('rfc', RandomForestClassifier())
#     ]
#
# vc = VotingClassifier(estimators=voting_set, voting='hard') # Also test voting='soft'

# %% [markdown]
# #**Similarities and dissimilarities from a machine learning perspective of Bagging, Boosting, Stacking, and Cascading**
#
# ![similarities and dissimilarities from a machine learning perspective of Bagging, Boosting, Stacking, and Cascading.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**What is Cross-Validation ?**
#
# **Answer:** Cross-validation is a technique for evaluating ML models by **training several ML models on subsets of the available input data** and **evaluating them on the `complementary subset` of the data**. Use cross-validation to **`detect overfitting`**
#
# **1. K-Fold Cross-validation: `Use K Values`**
#
# **2. Stratified K-Fold Cross-validation: `Use K Values for Each Class`**
#
# **3. Leave one out Cross-validation: `Use validation Each and Every Data point`**
#
# **4. Leave P out Cross-validation: `Use P value for very Subset of Data`**
#
#
# #**Geometric Intuition of K-Fold Cross-validation**
#
# Link: https://www.youtube.com/watch?v=PF2wLKv2lsI
# ![1_lOZqYqwmuW1lg6fitwqXxA.png](data:image/png;base64,...)
#
#
# **Code Implementation:**
#
# Link: https://www.geeksforgeeks.org/cross-validation-machine-learning/
#
# from sklearn.model_selection import cross_val_score, KFold
#
# number_of_folds = 5
#
# kf = KFold(n_splits=number_of_folds, shuffle=True, random_state=42)
#
# cross_val_results = cross_val_score(svm_classifier, X, y, cv=kf)
#
# print(f'Cross-Validation Results (Accuracy): {cross_val_results}')
#
# print(f'Mean Accuracy: {cross_val_results.mean()}')

# %% [markdown]
# #**What is confusion matrix ?**
#
# A confusion matrix is a **performance evaluation tool** in machine learning, **representing the accuracy of a classification model**. It displays the number of true positives, true negatives, false positives, and false negatives.

# %% [markdown]
# #**What is classification report ?**
#
# A classification report is a **text summary** that shows the main metrics for each class of a machine learning model. It usually includes the **precision, recall, F1-score**, and support for each class, as well as the **weighted average** of these metrics across all classes

# %% [markdown]
# #**What is F1-score ?**
#
# The F-score is a **measure of a model's accuracy on a dataset**. It is used to **evaluate binary classification systems**, which classify examples into 'positive' or 'negative'.

# %% [markdown]
# #**What is Precision ?**
#
# Precision is one indicator of a machine learning model's performance – **the quality of a positive prediction made by the model**. Precision refers to the **number of `true positives divided` by the total number of positive predictions** (i.e., the number of true positives plus the number of false positives).

# %% [markdown]
# #**What is Recall ?**
#
# Recall is a metric that **measures how often a machine learning model correctly identifies positive instances (true positives)** from all the **`actual positive samples`** in the dataset. You can **calculate recall by dividing the number of `true positives` by the number of positive instances**.
